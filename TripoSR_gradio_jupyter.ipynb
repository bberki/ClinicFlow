# %% [markdown]
# <a href="https://colab.research.google.com/github/bberki/ClinicFlow/blob/main/TripoSR_gradio_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/TripoSR-hf
# %cd /content/TripoSR-hf

# !pip install -q trimesh omegaconf einops rembg gradio onnxruntime
# !pip install -q torchmcubes

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/TripoSR/resolve/main/model.ckpt -d /content/model -o model.ckpt

# %cd /content/TripoSR-hf
# !python app.py
# Out:
# /content
# fatal: destination path 'TripoSR-hf' already exists and is not an empty directory.
# /content/TripoSR-hf
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 105.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.2 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torchmcubes (from versions: none)
# ERROR: No matching distribution found for torchmcubes
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e4ecf2|OK  |       0B/s|/content/model/model.ckpt
#
# Status Legend:
# (OK):download completed.
# /content/TripoSR-hf
# Traceback (most recent call last):
#   File "/content/TripoSR-hf/app.py", line 13, in <module>
# ...

# %%
import os
if os.path.exists('/content/TripoSR-hf'):
    # !rm -rf /content/TripoSR-hf

# %cd /content
# !git clone -b dev https://github.com/camenduru/TripoSR-hf
# %cd /content/TripoSR-hf
# Out:
# /content
# Cloning into 'TripoSR-hf'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 102 (delta 34), reused 95 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 444.55 KiB | 13.07 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/TripoSR-hf

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA version: 12.6
# CUDA device name: Tesla T4

# %%
import os
if os.path.exists('/content/TripoSR-hf'):
    # !rm -rf /content/TripoSR-hf

# %cd /content
# !git clone -b dev https://github.com/camenduru/TripoSR-hf
# %cd /content/TripoSR-hf
# Out:
# /content
# Cloning into 'TripoSR-hf'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 102 (delta 34), reused 95 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 444.55 KiB | 2.47 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/TripoSR-hf

# %% [markdown]
# **Reasoning**:
# The subtask is to verify the accessibility of the newly identified `torchmcubes` repository URL (`https://github.com/tatsy/torchmcubes`) using `curl -I`. This will confirm if the repository exists and is publicly accessible, which is crucial before attempting any cloning or downloading operations.

# %%
print("Attempting to curl the tatsy/torchmcubes repository page to check its existence and accessibility...")
# !curl -I https://github.com/tatsy/torchmcubes
print("Repository curl check complete.")
# Out:
# Attempting to curl the tatsy/torchmcubes repository page to check its existence and accessibility...
# HTTP/2 200
# date: Fri, 02 Jan 2026 10:17:34 GMT
# content-type: text/html; charset=utf-8
# vary: X-PJAX, X-PJAX-Container, Turbo-Visit, Turbo-Frame, X-Requested-With,Accept-Encoding, Accept, X-Requested-With
# etag: W/"05f6a8f1b9e5c9919a46f5afc3aa59c4"
# cache-control: max-age=0, private, must-revalidate
# strict-transport-security: max-age=31536000; includeSubdomains; preload
# x-frame-options: deny
# x-content-type-options: nosniff
# x-xss-protection: 0
# referrer-policy: no-referrer-when-downgrade
# ...

# %% [markdown]
# **Reasoning**:
# The previous `curl -I` command returned a 200 OK status, confirming that `https://github.com/tatsy/torchmcubes` is a valid and accessible GitHub repository. Now, I will proceed with installing `torchmcubes` directly from this correct GitHub repository using `pip install git+...`, ensuring all necessary build tools are also installed.

# %%
print("Installing build tools and then torchmcubes from tatsy/torchmcubes GitHub repository...")

# Ensure build tools are installed
# !apt-get update -qq
# !apt-get install -qq build-essential git cmake libgl1-mesa-glx

# Attempt to install torchmcubes from the correct GitHub repository (tatsy/torchmcubes).
# pip install git+https://github.com/tatsy/torchmcubes.git will clone the default branch (main/master).
# !pip install -q git+https://github.com/tatsy/torchmcubes.git

print("torchmcubes installation attempt from tatsy/torchmcubes GitHub complete.")

# Verify installation
try:
    import torchmcubes
    print("torchmcubes successfully imported.")
except ImportError:
    print("Failed to import torchmcubes after installation from tatsy/torchmcubes GitHub.")
# Out:
# Installing build tools and then torchmcubes from tatsy/torchmcubes GitHub repository...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# torchmcubes installation attempt from tatsy/torchmcubes GitHub complete.
# torchmcubes successfully imported.

# %% [markdown]
# **Reasoning**:
# The previous steps successfully installed `torchmcubes` from source. Now, I need to ensure that the `model.ckpt` file, which is a required model weight, is correctly downloaded. The initial notebook execution showed that the download resulted in a 0-byte file, so I will re-attempt the download to fix this.

# %%
print('Downloading model.ckpt...')
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/TripoSR/resolve/main/model.ckpt -d /content/model -o model.ckpt

print('Checking downloaded model size...')
# !ls -lh /content/model/model.ckpt
# Out:
# ...
# /bin/bash: line 1: aria2c: command not found
# Checking downloaded model size...
# ls: cannot access '/content/model/model.ckpt': No such file or directory

# %% [markdown]
# **Reasoning**:
# The previous attempt to download the model failed because `aria2c` was not found. I need to install `aria2` first to ensure the download tool is available, then re-attempt the model download.

# %%
print('Installing aria2...')
# !apt -y install -qq aria2

print('Downloading model.ckpt...')
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/TripoSR/resolve/main/model.ckpt -d /content/model -o model.ckpt

print('Checking downloaded model size...')
# !ls -lh /content/model/model.ckpt
# Out:
# Installing aria2...
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 54 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# ...

# %% [markdown]
# **Reasoning**:
# The previous steps successfully installed `torchmcubes` and downloaded `model.ckpt`. Now, I will install the remaining Python dependencies specified in the original notebook and then run the `app.py` to launch the TripoSR application.

# %%
print('Installing remaining dependencies...')
# !pip install -q trimesh omegaconf einops rembg gradio onnxruntime

print('Launching TripoSR application...')
# !python app.py
# Out:
# Installing remaining dependencies...
# Launching TripoSR application...
# 2026-01-02 10:49:26.969101: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767350967.002874   26900 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767350967.012940   26900 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767350967.037006   26900 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **Reasoning**:
# The `delete_cells` command is an agent-level action and cannot be executed within a Python code block, as confirmed by the repeated `NameError`. To correctly delete the specified cells, I must instruct the user to issue the `delete_cells` command directly, external to Python execution, as a separate agent command. This markdown block serves to provide those instructions clearly.
